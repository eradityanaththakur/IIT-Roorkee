# %% [markdown]
# <a href="https://colab.research.google.com/github/eradityanaththakur/IIT-Roorkee/blob/main/shape_and_pixel_values_of_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
# Replace '/tmp/image.jpg' with the path to your image file
image_path = '/shah-rukh-khan image.webp'

# %%
img.shape
# Out:
# (738, 1200, 3)

# %%
try:
    # Read the image
    img = cv2.imread(image_path)

    # Check if the image was loaded successfully
    if img is not None:
        # Print the pixel values of the image
        print("Image pixel values:")
        print(img)
    else:
        print(f"Error: Could not load image from {image_path}. Please check the path and file.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Image pixel values:
# [[[ 59 110 175]
#   [ 59 110 175]
#   [ 59 110 175]
#   ...
#   [207 220 229]
#   [216 229 239]
#   [209 222 232]]
#
#  [[ 59 110 175]
#   [ 59 110 175]
#   [ 59 110 175]
#   ...
#   [207 220 229]
#   [219 232 241]
#   [214 227 236]]
#
#  [[ 59 110 175]
#   [ 59 110 175]
#   [ 59 110 175]
#   ...
#   [208 221 230]
#   [222 235 244]
#   [219 232 241]]
#
#  ...
#
#  [[ 19  18  16]
#   [ 19  18  16]
#   [ 19  18  16]
#   ...
#   [ 46  47  49]
#   [ 46  47  49]
#   [ 46  47  49]]
#
#  [[ 18  17  15]
#   [ 18  17  15]
#   [ 19  18  16]
#   ...
#   [ 45  46  48]
#   [ 46  47  49]
#   [ 46  47  49]]
#
#  [[ 18  17  15]
#   [ 18  17  15]
#   [ 19  18  16]
#   ...
#   [ 45  46  48]
#   [ 46  47  49]
#   [ 46  47  49]]]

# %%
img.shape
# Out:
# (738, 1200, 3)

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print("Grayscale image pixel values:")
print(gray_img)
# Out:
# Grayscale image pixel values:
# [[124 124 124 ... 221 231 224]
#  [124 124 124 ... 221 233 228]
#  [124 124 124 ... 222 236 233]
#  ...
#  [ 18  18  18 ...  47  47  47]
#  [ 17  17  18 ...  46  47  47]
#  [ 17  17  18 ...  46  47  47]]

# %%
from google.colab.patches import cv2_imshow

print("Grayscale image:")
cv2_imshow(gray_img)
# Out:
# Grayscale image:
# <PIL.Image.Image image mode=L size=1200x738>

# %%
img.shape
# Out:
# (738, 1200, 3)

# %%
print("Grayscale image pixel values:")
print(gray_img)
# Out:
# Grayscale image pixel values:
# [[124 124 124 ... 221 231 224]
#  [124 124 124 ... 221 233 228]
#  [124 124 124 ... 222 236 233]
#  ...
#  [ 18  18  18 ...  47  47  47]
#  [ 17  17  18 ...  46  47  47]
#  [ 17  17  18 ...  46  47  47]]
